# %% [markdown]
# Step 1

# %%
import collections
import csv

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np


output1 = np.loadtxt('fixp_redox_sw1.txt', skiprows=2)
output2 = np.loadtxt('fixp_redox_sw5.txt', skiprows=2)
output3 = np.loadtxt('closed_redox_sw4.txt', skiprows=2)
output4 = np.loadtxt('closed_redox_sw5.txt', skiprows=2)
obv=np.loadtxt('Ultisol_control_gram2.csv',delimiter=",", skiprows=1,encoding='utf-8-sig')
#obv2=np.loadtxt('CO2_upland.csv', delimiter=",",encoding='utf-8-sig')
#obv3=np.loadtxt('CH4_upland.csv', delimiter=",",encoding='utf-8-sig')
plt.figure(figsize=(15,15))


fig, ax=plt.subplots(2,4)

plt.subplot(241)
plt.plot(output1[:,1],output1[:,3]*1000,'#8073ac')
plt.plot(output2[:,1],output2[:,3]*1000,'#b35806')
plt.plot(output3[:,1],output3[:,3]*1000,'#e08214')
#plt.plot(output4[:,1],output4[:,2]*1000,'#fdb863')
plt.title('DO (mmol)')


plt.subplot(242)
#plt.plot(obv[:,0],obv[:,1],marker="o",color='#fee0b6', linestyle="none")
plt.plot(output1[:,1],output1[:,20],'#7f3b08')
plt.plot(output2[:,1],output2[:,20],'#b35806')
#plt.plot(output3[:,0],output3[:,20],'#e08214')
#plt.plot(output4[:,0],output4[:,19],'#fdb863')
plt.title('CO2 (mg/g soil)')

plt.subplot(243)
plt.plot(output1[:,1],output1[:,5]*1000,'#7f3b08')
plt.plot(output2[:,1],output2[:,5]*1000,'#b35806')
plt.plot(output3[:,1],output3[:,5]*1000,'#e08214')
plt.plot(output4[:,1],output4[:,5]*1000,'#fdb863')
plt.title('CH4 (mmol)')

plt.subplot(244)
plt.plot(output1[:,1],output1[:,4]*1000,'#7f3b08')
plt.plot(output2[:,1],output2[:,4]*1000,'#b35806')
plt.plot(output3[:,1],output3[:,4]*1000,'#e08214')
plt.plot(output4[:,1],output4[:,4]*1000,'#fdb863')
plt.title('HS (mmol)')

plt.subplot(245)
plt.plot(output1[:,1],output1[:,22],'#7f3b08')
plt.plot(output2[:,1],output2[:,22],'#b35806')
plt.plot(output3[:,1],output3[:,22],'#e08214')
plt.plot(output4[:,1],output4[:,22],'#fdb863')
plt.title('OrganicAcids (mg/g soil)')

plt.subplot(246)
plt.plot(output1[:,1],output1[:,16],'#7f3b08')
#plt.plot(output2[:,0],output2[:,15],'#b35806')
#plt.plot(output3[:,0],output3[:,15],'#e08214')
#plt.plot(output4[:,0],output4[:,15],'#fdb863')
plt.title('DOM (mg/g soil)')

plt.subplot(247)
plt.plot(output1[:,1],output1[:,17],'#7f3b08')
#plt.plot(output2[:,0],output2[:,16],'#b35806')
#plt.plot(output3[:,0],output3[:,16],'#e08214')
#plt.plot(output4[:,0],output4[:,16],'#fdb863')
plt.title('BA (mg/g soil)')

plt.subplot(248)
plt.plot(output1[:,1],output1[:,8]/1000,'#7f3b08', label="sw1")
plt.plot(output2[:,1],output2[:,8]/1000,'#b35806', label="sw2")
plt.plot(output3[:,1],output3[:,8]/1000,'#e08214', label="sw3")
plt.plot(output4[:,1],output4[:,8]/1000,'#fdb863', label="sw4")
plt.title('SC (ds/m)')
plt.legend(loc="best")

plt.suptitle("MEND_Redox_sw1-4")

fig.tight_layout()
plt.show()

# %%
##solution 1, 2, 3 representing SOM binding weight-0.25,0.5,1--reactive sites bind with Ca2+
test1 = np.loadtxt('fixp_redox_sw5.txt', skiprows=2)
plt.figure()

fig, ax=plt.subplots(2,1)

plt.subplot(211)
plt.plot(test1[:,1],test1[:,26],'#b35806', label="Aero")
plt.plot(test1[:,1],test1[:,27],'#8073ac', label="SurR")
plt.plot(test1[:,1],test1[:,28],'#1f78b4', label="Meth")
plt.legend(loc="best")
plt.title("closed system")

plt.subplot(212)
plt.plot(test1[:,1],test1[:,26]/(test1[:,26]+test1[:,27]+test1[:,28]),'#b35806')
plt.plot(test1[:,1],test1[:,27]/(test1[:,26]+test1[:,27]+test1[:,28]),'#8073ac')
plt.plot(test1[:,1],test1[:,28]/(test1[:,26]+test1[:,27]+test1[:,28]),'#1f78b4')

fig.tight_layout()

plt.show()
# Out:
# <ipython-input-401-6e5eab72b126>:15: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(test1[:,1],test1[:,26]/(test1[:,26]+test1[:,27]+test1[:,28]),'#b35806')
# <ipython-input-401-6e5eab72b126>:16: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(test1[:,1],test1[:,27]/(test1[:,26]+test1[:,27]+test1[:,28]),'#8073ac')
# <ipython-input-401-6e5eab72b126>:17: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(test1[:,1],test1[:,28]/(test1[:,26]+test1[:,27]+test1[:,28]),'#1f78b4')

# %%
output1 = np.loadtxt('fixp_redox_sw1.txt', skiprows=2)
output2 = np.loadtxt('closed_redox_sw2.txt', skiprows=2)
output3 = np.loadtxt('closed_redox_sw3.txt', skiprows=2)
output4 = np.loadtxt('closed_redox_sw5.txt', skiprows=2)
#obv=np.loadtxt('Ultisol_control.csv',delimiter=",", skiprows=1)
#obv2=np.loadtxt('CO2_upland.csv', delimiter=",",encoding='utf-8-sig')
#obv3=np.loadtxt('CH4_upland.csv', delimiter=",",encoding='utf-8-sig')
plt.figure(figsize=(15,15))



plt.plot(output1[:,1],output1[:,3]*1000,'#8073ac')
plt.plot(output2[:,0],output2[:,2]*1000,'#b35806')
plt.plot(output3[:,0],output3[:,2]*1000,'blue')
plt.plot(output4[:,0],output4[:,2]*1000,'#fdb863')
plt.title('DO (mmol)')
# Out:
# Text(0.5, 1.0, 'DO (mmol)')
