# %% [markdown]
# Step 1

# %%
import collections
import csv

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

ref = np.loadtxt('Ex1_ref_f1.txt', skiprows=1)
output1 = np.loadtxt('Ex1_agg_f1.txt', skiprows=1)
output2 = np.loadtxt('Ex1_both_f1.txt', skiprows=1)
output3 = np.loadtxt('Ex1_agg_f3.txt', skiprows=1)
output4 = np.loadtxt('Ex1_agg_f4.txt', skiprows=1)
obv=np.loadtxt('Brazil_obv.csv',delimiter=",", skiprows=1)

plt.figure(figsize=(15,9))


fig, ax=plt.subplots(3,3)

plt.subplot(331)
plt.plot(ref[:,2],ref[:,21],'#8073ac')
plt.plot(output1[:,2],output1[:,21],'#7f3b08')
plt.plot(output2[:,2],output2[:,21],'#b35806')
plt.plot(output3[:,2],output3[:,21],'#e08214')
plt.plot(output4[:,2],output4[:,21],'#fdb863')
plt.title('DOM')

plt.subplot(332)
plt.plot(ref[:,2],ref[:,22],'#8073ac')
plt.plot(output1[:,2],output1[:,22],'#7f3b08')
plt.plot(output2[:,2],output2[:,22],'#b35806')
plt.plot(output3[:,2],output3[:,22],'#e08214')
plt.plot(output4[:,2],output4[:,22],'#fdb863')
plt.title('BA')

plt.subplot(333)
plt.plot(ref[:,2],ref[:,18],'#8073ac')
plt.plot(output1[:,2],output1[:,18],'#7f3b08')
plt.plot(output2[:,2],output2[:,18],'#b35806')
plt.plot(output3[:,2],output3[:,18],'#e08214')
plt.plot(output4[:,2],output4[:,18],'#fdb863')
plt.title('POM')

plt.subplot(334)
plt.plot(ref[:,2],ref[:,24],'#8073ac')
plt.plot(output1[:,2],output1[:,24],'#7f3b08')
plt.plot(output2[:,2],output2[:,24],'#b35806')
plt.plot(output3[:,2],output3[:,24],'#e08214')
plt.plot(output4[:,2],output4[:,24],'#fdb863')
plt.title('EM')

plt.subplot(335)
plt.plot(ref[:,2],ref[:,23],'#8073ac')
plt.plot(output1[:,2],output1[:,23],'#7f3b08')
plt.plot(output2[:,2],output2[:,23],'#b35806')
plt.plot(output3[:,2],output3[:,23],'#e08214')
#plt.plot(output4[:,2],output4[:,23],'#fdb863')
plt.title('EP')

plt.subplot(336)
plt.plot(ref[:,2],ref[:,25],'#8073ac')
plt.plot(output1[:,2],output1[:,25],'#7f3b08')
plt.plot(output2[:,2],output2[:,25],'#b35806')
plt.plot(output3[:,2],output3[:,25],'#e08214')
plt.plot(output4[:,2],output4[:,25],'#fdb863')
plt.plot(obv[:,0],obv[:,1],".")
plt.title('IC')

plt.subplot(337)
plt.plot(ref[:,2],ref[:,29],'#8073ac')
plt.plot(output1[:,2],output1[:,29],'#7f3b08')
plt.plot(output2[:,2],output2[:,29],'#b35806')
plt.plot(output3[:,2],output3[:,29],'#e08214')
#plt.plot(output4[:,2],output4[:,29],'#fdb863')
plt.title('CaPO4')


plt.subplot(338)
plt.plot(ref[:,2],ref[:,13]/1000,'#8073ac',label="Ref")
plt.plot(output1[:,2],output1[:,13]/1000,'#7f3b08', label="Ex2_f1")
plt.plot(output2[:,2],output2[:,13]/1000,'#b35806', label="Ex2_f2")
plt.plot(output3[:,2],output3[:,13]/1000,'#e08214', label="Ex2_f3")
plt.plot(output4[:,2],output4[:,13]/1000,'#fdb863', label="Ex2_f4")
#plt.legend(loc="lower right")
plt.title('SC (dS/m)')

plt.subplot(339)
plt.plot(output1[:,2],output1[:,14],'#7f3b08')
plt.plot(output1[:,2],output1[:,15],'#b35806')
plt.plot(output1[:,2],output1[:,16],'#e08214')
plt.plot(output1[:,2],output1[:,17],'#fdb863')
plt.title('fsal')


plt.suptitle("Rsal_ref_Ex2")

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

##solution 1, 2, 3 representing SOM binding weight-0.25,0.5,1--reactive sites bind with Ca2+
output1 = np.loadtxt('vanD_clay_fresh_a.txt', skiprows=1)
output3 = np.loadtxt('vanD_clay_salt_a.txt', skiprows=1)
obv1=np.loadtxt('clay_fresh.csv',delimiter=",",skiprows=1)
obv3=np.loadtxt('clay_salt.csv',delimiter=",",skiprows=1)
output1ex = np.loadtxt('vanD_clay_fresh_c.txt', skiprows=1)
output3ex = np.loadtxt('vanD_clay_salt_c.txt', skiprows=1)


plt.figure()

fig, ax=plt.subplots(3,3)
plt.subplot(331)
plt.plot(output1[:,0],'#fee0b6',output3[:,0],'#7f3b08', linestyle="dashed")
plt.plot(output1[:,0],'#fee0b6',output3[:,0],'#7f3b08')
plt.plot(obv1[:,0],marker="o",color='#fee0b6', linestyle="none")
plt.plot(obv3[:,0],color='#7f3b08',marker="o", linestyle="none")
plt.title('pH')

plt.subplot(332)
plt.plot(output1[:,10]/1000,'#fee0b6',output3[:,10]/1000,'#7f3b08', linestyle="dashed")
plt.plot(output1ex[:,10]/1000,'#fee0b6',output3ex[:,10]/1000,'#7f3b08')
plt.title('SC (ds/m)')

plt.subplot(333)
plt.plot(output1[:,8]*1000,'#fee0b6',output3[:,8]*1000,'#7f3b08', linestyle="dashed")
plt.plot(output1ex[:,8]*1000,'#fee0b6',output3ex[:,8]*1000,'#7f3b08')
plt.plot(obv1[:,7],marker="o",color='#fee0b6', linestyle="none")
plt.plot(obv3[:,7],color='#7f3b08',marker="o", linestyle="none")
plt.title('NH4(mM)')

plt.subplot(334)
plt.plot(output1[:,3]*1000,'#fee0b6',output3[:,3]*1000,'#7f3b08', linestyle="dashed")
plt.plot(output1ex[:,3]*1000,'#fee0b6',output3ex[:,3]*1000,'#7f3b08')
plt.plot(obv1[:,3],marker="o",color='#fee0b6', linestyle="none")
plt.plot(obv3[:,3],color='#7f3b08',marker="o", linestyle="none")
plt.title('Ca(mM)')

plt.subplot(335)
plt.plot(output1[:,4]*1000,'#fee0b6',output3[:,4]*1000,'#7f3b08', linestyle="dashed")
plt.plot(output1ex[:,4]*1000,'#fee0b6',output3ex[:,4]*1000,'#7f3b08')
plt.plot(obv1[:,4],marker="o",color='#fee0b6', linestyle="none")
plt.plot(obv3[:,4],color='#7f3b08',marker="o", linestyle="none")
plt.title('Mg(mM)')

plt.subplot(336)
plt.plot(output1[:,1]*1000,'#fee0b6',output3[:,1]*1000,'#7f3b08')
plt.plot(output1ex[:,1]*1000,'#fee0b6',output3ex[:,1]*1000,'#7f3b08', linestyle="dashed")
plt.plot(obv1[:,1],marker="o",color='#fee0b6', linestyle="none")
plt.plot(obv3[:,1],color='#7f3b08',marker="o", linestyle="none")
plt.title('Na(mM)')

plt.subplot(337)
plt.plot(output1[:,7]*1000,'#fee0b6',output3[:,7]*1000,'#7f3b08', linestyle="dashed")
plt.plot(output1ex[:,7]*1000,'#fee0b6',output3ex[:,7]*1000,'#7f3b08')
plt.plot(obv1[:,8],marker="o",color='#fee0b6', linestyle="none")
plt.plot(obv3[:,8],color='#7f3b08',marker="o", linestyle="none")
plt.title('SO4(mM)')

plt.subplot(338)
plt.plot(output1[:,6]*1000,'#fee0b6',output3[:,6]*1000,'#7f3b08', linestyle="dashed")
plt.plot(output1ex[:,6]*1000,'#fee0b6',output3ex[:,6]*1000,'#7f3b08')
plt.plot(obv1[:,6],marker="o",color='#fee0b6', linestyle="none")
plt.plot(obv3[:,6],color='#7f3b08',marker="o", linestyle="none")
plt.title('Cl (mM)')

plt.subplot(339)
plt.plot(output1[:,5]*1000,'#fee0b6', linestyle="dashed")
plt.plot(output3[:,5]*1000,'#7f3b08', linestyle="dashed")
plt.plot(output1ex[:,5]*1000,'#fee0b6',output3ex[:,5]*1000,'#7f3b08')
plt.plot(obv1[:,5],marker="o",color='#fee0b6', linestyle="none")
plt.plot(obv3[:,5],color='#7f3b08',marker="o", linestyle="none")
plt.title('PO4(mM)')
#plt.legend(loc="upper left")
plt.suptitle("Peat fresh (light)-salty (dark)")

fig.tight_layout()
plt.show()
