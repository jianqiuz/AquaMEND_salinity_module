# %% [markdown]
# Step 1

# %%
import collections
import csv

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

output1 = np.loadtxt('cue_sul_fs1.txt', skiprows=1)
#output4 = np.loadtxt('Rsalt_ref_Ex1_sorp_f4.txt', skiprows=1)
obv=np.loadtxt('Brazil_obv.csv',delimiter=",", skiprows=1)


plt.figure()

fig, ax=plt.subplots(3,4)
plt.subplot(341)
plt.plot(output1[:,0],output1[:,15],'#7f3b08')
plt.title('DOM')

plt.subplot(342)
plt.plot(output1[:,0],output1[:,16],'#7f3b08')
plt.title('BA')

plt.subplot(343)
plt.plot(output1[:,0],output1[:,12],'#7f3b08')
plt.title('POM')

plt.subplot(344)
plt.plot(output1[:,0],output1[:,17],'#7f3b08')
plt.title('EP')

plt.subplot(345)
plt.plot(output1[:,0],output1[:,18],'#7f3b08')
plt.title('EM')

plt.subplot(346)
plt.plot(output1[:,0],output1[:,19],'#7f3b08')
plt.plot(obv[:,0],obv[:,1],".")
plt.title('IC')

plt.subplot(347)
plt.plot(output1[:,0],output1[:,14],'#7f3b08')

plt.title('QOM')


plt.subplot(348)
plt.plot(output1[:,0],output1[:,13],'#7f3b08')
plt.title('MAOM')

plt.subplot(349)
plt.plot(output1[:,0],output1[:,7],'#7f3b08')
plt.title('SC')

plt.subplot(3,4,10)
plt.plot(output1[:,0],output1[:,2],'#7f3b08')
plt.title('DO')

plt.subplot(3,4,11)
plt.plot(output1[:,0],output1[:,4],'#7f3b08')
plt.title('CH4')

plt.subplot(3,4,12)
plt.plot(output1[:,0],output1[:,3],'#7f3b08')
plt.title('HS')


plt.suptitle("Vaero=0.2")

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

#ref = np.loadtxt('Ex1_ref.txt', skiprows=1)
output1 = np.loadtxt('mort_sul_fs1.txt', skiprows=2)
output2 = np.loadtxt('mort_sul_fs2.txt', skiprows=2)
output3 = np.loadtxt('mort_sul_fs3.txt', skiprows=2)
output4 = np.loadtxt('mort_sul_fs4.txt', skiprows=1)
obv=np.loadtxt('Brazil_obv.csv',delimiter=",", skiprows=1)

plt.figure(figsize=(15,9))


fig, ax=plt.subplots(2,3)

plt.subplot(231)
plt.plot(output1[:,2],output1[:,21],'#542788')
plt.plot(output2[:,2],output2[:,21],'#b35806')
plt.plot(output3[:,2],output3[:,21],'#fdb863')
plt.plot(output4[:,2],output4[:,21],'#b2abd2')
plt.title('DOM')

plt.subplot(232)
plt.plot(output1[:,2],output1[:,22],'#542788')
plt.plot(output2[:,2],output2[:,22],'#b35806')
plt.plot(output3[:,2],output3[:,22],'#fdb863')
plt.plot(output4[:,2],output4[:,22],'#b2abd2')
plt.title('BA')

plt.subplot(233)
plt.plot(output1[:,2],output1[:,20],'#7f3b08')
plt.plot(output1[:,2],output1[:,20],'#b35806')
plt.plot(output1[:,2],output1[:,20],'#fdb863')
plt.plot(output1[:,2],output1[:,17],'#b2abd2')
plt.title('QOM')

plt.subplot(234)
plt.plot(output1[:,2],output1[:,24],'#542788')
plt.plot(output2[:,2],output2[:,24],'#b35806')
plt.plot(output3[:,2],output3[:,24],'#fdb863')
plt.plot(output4[:,2],output4[:,24],'#b2abd2')
plt.title('EM')

plt.subplot(235)
plt.plot(output1[:,2],output1[:,23],'#542788')
plt.plot(output2[:,2],output2[:,23],'#b35806')
plt.plot(output3[:,2],output3[:,23],'#fdb863')
plt.plot(output4[:,2],output4[:,23],'#b2abd2')
plt.title('EP')

plt.subplot(236)
#plt.plot(ref[:,2],ref[:,25],'blue')
plt.plot(output1[:,0],output1[:,19],'#542788')
plt.plot(output2[:,0],output2[:,19],'#b35806')
plt.plot(output3[:,0],output3[:,19],'#fdb863')
plt.plot(output4[:,0],output4[:,19],'#b2abd2')
plt.plot(obv[:,0],obv[:,1],".")
plt.title('IC')




plt.suptitle("Abio-sorption")

fig.tight_layout()
plt.show()
