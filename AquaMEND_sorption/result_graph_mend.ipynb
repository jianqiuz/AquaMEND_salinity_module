# %% [markdown]
# Step 1

# %%
import collections
import csv

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

#ref = np.loadtxt('Ex1_ref.txt', skiprows=1)
output1 = np.loadtxt('Ex1_ref_max1.txt', skiprows=2)
output2 = np.loadtxt('Ex1_ref_max2.txt', skiprows=2)
output3 = np.loadtxt('Ex1_ref_max3.txt', skiprows=2)
output4 = np.loadtxt('Ex1_ref_max4.txt', skiprows=1)
obv=np.loadtxt('Brazil_obv.csv',delimiter=",", skiprows=1)

plt.figure(figsize=(15,9))


fig, ax=plt.subplots(2,3)

plt.subplot(231)
plt.plot(output1[:,2],output1[:,21],'#542788')
plt.plot(output2[:,2],output2[:,21],'#b35806')
plt.plot(output3[:,2],output3[:,21],'#fdb863')
plt.plot(output4[:,2],output4[:,21],'#ffff99')
plt.title('DOM')

plt.subplot(232)
plt.plot(output1[:,2],output1[:,22],'#542788')
plt.plot(output2[:,2],output2[:,22],'#b35806')
plt.plot(output3[:,2],output3[:,22],'#fdb863')
plt.plot(output4[:,2],output4[:,22],'#ffff99')
plt.title('BA')

plt.subplot(233)
plt.plot(output1[:,2],output1[:,20],'#7f3b08')
plt.plot(output1[:,2],output1[:,20],'#b35806')
plt.plot(output1[:,2],output1[:,20],'#fdb863')
plt.plot(output1[:,2],output1[:,17],'#ffff99')
plt.title('QOM')

plt.subplot(234)
plt.plot(output1[:,2],output1[:,24],'#542788')
plt.plot(output2[:,2],output2[:,24],'#b35806')
plt.plot(output3[:,2],output3[:,24],'#fdb863')
plt.plot(output4[:,2],output4[:,24],'#ffff99')
plt.title('EM')

plt.subplot(235)
plt.plot(output1[:,2],output1[:,23],'#542788')
plt.plot(output2[:,2],output2[:,23],'#b35806')
plt.plot(output3[:,2],output3[:,23],'#fdb863')
plt.plot(output4[:,2],output4[:,23],'#ffff99')
plt.title('EP')

plt.subplot(236)
#plt.plot(ref[:,2],ref[:,25],'blue')
plt.plot(output1[:,2],output1[:,25],'#542788')
plt.plot(output2[:,2],output2[:,25],'#b35806')
plt.plot(output3[:,2],output3[:,25],'#fdb863')
plt.plot(output4[:,2],output4[:,25],'#ffff99')
plt.plot(obv[:,0],obv[:,1],".")
plt.title('IC')




plt.suptitle("Abio-sorption")

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

output1 = np.loadtxt('Ex1_ref.txt', skiprows=1)
#output4 = np.loadtxt('Rsalt_ref_Ex1_sorp_f4.txt', skiprows=1)
obv=np.loadtxt('Brazil_obv.csv',delimiter=",", skiprows=1)


plt.figure()

fig, ax=plt.subplots(3,3)
plt.subplot(331)
plt.plot(output1[:,2],output1[:,21],'#7f3b08')
plt.title('DOM')

plt.subplot(332)
plt.plot(output1[:,2],output1[:,22],'#7f3b08')
plt.title('BA')

plt.subplot(333)
plt.plot(output1[:,2],output1[:,18],'#7f3b08')
plt.title('POM')

plt.subplot(334)
plt.plot(output1[:,2],output1[:,24],'#7f3b08')
plt.title('EM')

plt.subplot(335)
plt.plot(output1[:,2],output1[:,23],'#7f3b08')
plt.title('EP')

plt.subplot(336)
plt.plot(output1[:,2],output1[:,25],'#7f3b08')
plt.plot(obv[:,0],obv[:,1],".")
plt.title('IC')

plt.subplot(337)
plt.plot(output1[:,2],output1[:,20],'#7f3b08')

plt.title('QOM')


plt.subplot(338)
plt.plot(output1[:,2],output1[:,19],'#7f3b08')
plt.title('MAOM')

plt.subplot(339)
plt.plot(output1[:,2],output1[:,13],'#7f3b08')
plt.title('SC')

plt.suptitle("Input_test")

fig.tight_layout()
plt.show()
