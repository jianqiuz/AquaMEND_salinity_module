# %% [markdown]
# Step 1

# %%
import collections
import csv

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

##solution 1, 2, 3 representing SOM binding weight-0.25,0.5,1--reactive sites bind with Ca2+
output1 = np.loadtxt('soil_solution1.txt', skiprows=1)
output2 = np.loadtxt('soil_solution2.txt', skiprows=1)
output3 = np.loadtxt('soil_solution3.txt', skiprows=1)

plt.figure()
plt.subplot(241)
plt.plot(output1[:,0],'c',output2[:,0],'b',output3[:,0],'k')
plt.title('pH')

plt.subplot(242)
plt.plot(output1[:,9],'c',output2[:,9],'b',output3[:,9],'k')
plt.title('SC')

plt.subplot(243)
plt.plot(output1[:,2],'c',output2[:,2],'b',output3[:,2],'k')
plt.title('K')

plt.subplot(244)
plt.plot(output1[:,3],'c',output2[:,3],'b',output3[:,3],'k')
plt.title('Ca')

plt.subplot(245)
plt.plot(output1[:,4],'c',output2[:,4],'b',output3[:,4],'k')
plt.title('Mg')

plt.subplot(246)
plt.plot(output1[:,5],'c',output2[:,5],'b',output3[:,5],'k')
plt.title('NO3')

plt.subplot(247)
plt.plot(output1[:,6],'c',output2[:,6],'b',output3[:,6],'k')
plt.title('Cl')

plt.subplot(248)
plt.plot(output1[:,7],'c',output2[:,7],'b',output3[:,7],'k')
plt.title('SO4')

plt.show()

# %%
import matplotlib.pyplot as plt
